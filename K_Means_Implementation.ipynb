# %% [markdown]
# <a href="https://colab.research.google.com/github/akanupam/ML_learings/blob/main/K_Means_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
k = 3

points = np.array(
    [
        [2,10],
        [2,5],
        [8,4],
        [5,8],
        [7,5],
        [6,4],
        [1,2],
        [4,9]
    ]
)

initial_centers = np.array([
        [2,10],
        [2,5],
        [8,4]
])

# %%
kmeans = KMeans(n_clusters=k, init= initial_centers, n_init=1)

# %%
kmeans.fit(points)
# Out:
# KMeans(init=array([[ 2, 10],
#        [ 2,  5],
#        [ 8,  4]]), n_clusters=3,
#        n_init=1)

# %%
final_centers = kmeans.cluster_centers_
final_clusters = kmeans.labels_

# %%
final_centers
# Out:
# array([[3.66666667, 9.        ],
#        [1.5       , 3.5       ],
#        [7.        , 4.33333333]])

# %%
final_clusters
# Out:
# array([0, 1, 2, 0, 2, 2, 1, 0], dtype=int32)

# %%
colors = ['r','g','b']

for i in range(k):
  cluster_points = points[final_clusters==i]
  plt.scatter(cluster_points[:,0],cluster_points[:,1], c = colors[i], label = f'cluster {i+1}')

plt.scatter(final_centers[:,0],final_centers[:,1] ,c = 'black',marker = 'x', s = 100, label = 'centers')
plt.title("K-Means Clusteing")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %%
n_samples = 300
n_features = 2
n_clusters = 3
points, true_labels = make_blobs(n_samples=n_samples, n_features=n_features, centers = n_clusters)

# %%
true_labels
# Out:
# array([1, 2, 1, 1, 0, 2, 0, 0, 0, 1, 0, 1, 2, 1, 1, 1, 1, 2, 1, 0, 0, 0,
#        1, 0, 1, 1, 0, 2, 2, 2, 1, 0, 1, 0, 1, 2, 0, 0, 0, 2, 1, 0, 2, 2,
#        1, 1, 1, 2, 2, 0, 2, 2, 1, 1, 0, 2, 2, 2, 1, 1, 2, 2, 0, 0, 1, 1,
#        2, 0, 0, 2, 0, 1, 0, 0, 0, 2, 0, 1, 1, 1, 2, 0, 2, 2, 2, 2, 1, 1,
#        2, 1, 2, 2, 2, 0, 1, 0, 2, 1, 2, 1, 1, 1, 2, 1, 0, 2, 0, 0, 2, 0,
#        2, 2, 1, 2, 1, 0, 1, 0, 1, 2, 2, 2, 0, 1, 0, 0, 1, 2, 0, 2, 1, 1,
#        0, 2, 2, 0, 1, 2, 1, 1, 0, 2, 2, 2, 1, 2, 2, 2, 0, 0, 0, 2, 1, 1,
#        0, 1, 0, 2, 0, 1, 2, 0, 0, 1, 0, 1, 2, 1, 0, 1, 0, 2, 1, 0, 0, 0,
#        0, 0, 1, 1, 2, 1, 2, 1, 2, 1, 0, 2, 0, 1, 0, 0, 0, 0, 1, 2, 1, 2,
#        0, 0, 0, 1, 2, 1, 1, 2, 0, 0, 0, 2, 2, 0, 1, 0, 1, 0, 1, 0, 2, 0,
#        0, 0, 2, 2, 1, 0, 0, 0, 1, 2, 0, 2, 2, 0, 0, 2, 2, 0, 1, 0, 2, 2,
#        1, 1, 0, 2, 2, 1, 1, 2, 1, 2, 2, 1, 0, 1, 0, 0, 1, 2, 1, 1, 1, 2,
#        1, 1, 0, 1, 1, 1, 2, 0, 2, 2, 2, 2, 2, 0, 1, 2, 1, 0, 2, 0, 2, 0,
# ...

# %%
model = KMeans(n_clusters=n_clusters)
model.fit(points)
# Out:
# KMeans(n_clusters=3)

# %%
final_clusters = model.labels_

# %%
final_centers = model.cluster_centers_

# %%
plt.figure(figsize=(8,6))
colors = ['r','g','b']

for i in range(k):
  cluster_points = points[final_clusters==i]
  plt.scatter(cluster_points[:,0],cluster_points[:,1], c = colors[i], label = f'cluster {i+1}')

plt.scatter(final_centers[:,0],final_centers[:,1] ,c = 'black',marker = 'x', s = 100, label = 'centers')
plt.title("K-Means Clusteing")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()
